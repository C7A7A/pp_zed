# %% [markdown]
# # Topic modeling
#
# Zadanie proszę wykonać w parach, ale... na dwóch komputerach. Na obu komputerach proszę najpierw wykonać instrukcje z sekcji **Przygotowanie**. Następnie na jednym komputerze proszę od razu odkomentować i uruchomić kod w sekcji **Wikipedia** i **Wizualizacja**. Na drugim komputerze proszę rozwiązać zadania z sekcji **Tweety** i **Wizualizacja**.
#
# Po wykonaniu tego zadania powinieneś:
# + potrafić wykonać podstawowy topic modeling,
# + umieć stworzyć słownik mapujący identyfikatory na słowa,
# + potrafić stworzyć macierz wektorów TF-IDF,
# + wiedzieć jak wykorzystać LDA do określenia proporcji tematów w nowym dokumencie tekstowym,
# + potrafić zwizualizować wyniki algorytmu LDA.
#
# Do wykonania zadania wykorzystamy bibliotekę [gensim](https://radimrehurek.com/gensim/), która oferuje szereg metod do analizy tekstu. Warto w wolnej chwili zobaczyć co oprócz algorytmu LDA zostało zaimplementowane w ramach tego modułu!

# %% [markdown]
# ## Przygotowanie
#
# Aby zadziałała wizualizacja, musimy najpierw zauktualizować bibliotekę `scipy` i doinstalować bibliotekę `pyldavis`. Będzie to okazja, żeby zobaczyć jak zarządza się bibliotekami w anacondzie. Jeśli kogoś interesuje co oznaczają kolejne komendy, proszę zajrzeć do [dokumentacji Anacondy](http://conda.pydata.org/docs/using/pkgs.html).
#
# 1. Zatrzymaj kernel (serwer jupyter notebooka)
# 2. Otwórz terminal
# 3. Wpisz `conda update scipy` (i Enter gdy spytają `Proceed`)
# 4. Popatrz na paski postępu
# 5. Wpisz `activate root`
# 6. Wpisz `pip install pyldavis`
# 7. Wpisz `deactivate`
#
# Koniec. Możesz ponownie odpalić notatnik i przejść do kolejnych kroków.

# %% [markdown]
# ## Wikipedia
#
# Ten fragemnt kodu stanowi przykład uruchomienia topic modelingu na większym zbiorze danych. Ponieważ wyliczenie modelu będzie trwać od kilku do kilkunastu minut, niech każda para uruchomi ten przykład tylko na jednym komputerze.
#
# Aby uruchomić przykład, w folderze z notatnikiem muszą znajdować się pliki `wiki_wordids.txt.bz2` i `wiki_tfidf.mm` ściągnięte wraz z notatnikiem. Przykład zbudowany jest w oparciu o podzbiór stron wikipedii dostępny pod adresem: https://dumps.wikimedia.org/enwiki/latest/. Strony zostały przekonwertowane na reprezentację wektorową za pomocą skryptu:
# `python -m gensim.scripts.make_wiki`.
#
# **Przeczytaj komentarze zanim uruchomisz kod.**

# %%
import logging
import gensim

# # Włączamy logowanie, żeby śledzić postępy algorytmu (to akurat nie będzie działać w Jupyter Notebooku,
# # ale warto o tym wspomnieć)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# # Odczytujemy z pliku mapowanie/słownik id->słowo
id2word = gensim.corpora.Dictionary.load_from_text('wiki_wordids.txt.bz2')

# # Odczytujemy z pliku reprezentację wektorową korpusu (macierz wetkorów TF-IDF)
mm = gensim.corpora.MmCorpus('wiki_tfidf.mm')
print(mm)

# # Tworzymy model LDA z 20 grupami wykonując 20 iteracji na całym zbiorze
lda = gensim.models.LdaMulticore(corpus=mm, id2word=id2word, num_topics=20, passes=20, workers=4)
# # Alternatywnie w razie problemów z wielowątkowością:
# # lda = gensim.models.ldamodel.LdaModel(corpus=mm, id2word=id2word, num_topics=20, update_every=0, passes=20)
lda.print_topics(20)
# Out:
# 2024-01-29 10:49:54,557 : WARNING : Text does not contain num_docs on the first line.
# 2024-01-29 10:49:54,601 : INFO : initializing cython corpus reader from wiki_tfidf.mm
# 2024-01-29 10:49:54,601 : INFO : accepted corpus with 4672 documents, 19960 features, 1762996 non-zero entries
# 2024-01-29 10:49:54,601 : INFO : using symmetric alpha at 0.05
# 2024-01-29 10:49:54,601 : INFO : using symmetric eta at 0.05
# 2024-01-29 10:49:54,605 : INFO : using serial LDA version on this node
# 2024-01-29 10:49:54,629 : INFO : running online LDA training, 20 topics, 20 passes over the supplied corpus of 4672 documents, updating every 8000 documents, evaluating every ~4672 documents, iterating 50x with a convergence threshold of 0.001000
# 2024-01-29 10:49:54,633 : INFO : training LDA model using 4 processes
# MmCorpus(4672 documents, 19960 features, 1762996 non-zero entries)
# 2024-01-29 10:49:58,324 : INFO : PROGRESS: pass 0, dispatched chunk #0 = documents up to #2000/4672, outstanding queue size 1
# 2024-01-29 10:49:59,095 : INFO : PROGRESS: pass 0, dispatched chunk #1 = documents up to #4000/4672, outstanding queue size 2
# 2024-01-29 10:49:59,481 : INFO : PROGRESS: pass 0, dispatched chunk #2 = documents up to #4672/4672, outstanding queue size 3
# 2024-01-29 10:50:00,285 : INFO : topic #9 (0.050): 0.001*"cell" + 0.001*"jpg" + 0.001*"djibouti" + 0.001*"singer" + 0.001*"cameroon" + 0.001*"comoros" + 0.001*"fiction" + 0.001*"actor" + 0.001*"politician" + 0.001*"bass"
# 2024-01-29 10:50:00,285 : INFO : topic #8 (0.050): 0.001*"columbus" + 0.001*"alexandria" + 0.001*"afghanistan" + 0.001*"medicine" + 0.001*"km" + 0.001*"classification" + 0.001*"guitar" + 0.001*"apollo" + 0.001*"bell" + 0.001*"plants"
# 2024-01-29 10:50:00,285 : INFO : topic #16 (0.050): 0.001*"aircraft" + 0.001*"dna" + 0.001*"christmas" + 0.001*"cell" + 0.001*"aim" + 0.001*"missile" + 0.001*"basque" + 0.001*"hebrew" + 0.001*"enemy" + 0.001*"constellation"
# 2024-01-29 10:50:00,285 : INFO : topic #6 (0.050): 0.001*"album" + 0.001*"actor" + 0.001*"carbon" + 0.001*"singer" + 0.001*"jpg" + 0.001*"afghanistan" + 0.001*"algorithm" + 0.001*"football" + 0.001*"amber" + 0.001*"ball"
# 2024-01-29 10:50:00,289 : INFO : topic #10 (0.050): 0.001*"px" + 0.001*"alfonso" + 0.001*"egypt" + 0.001*"album" + 0.001*"el" + 0.001*"baku" + 0.001*"chad" + 0.001*"burkina" + 0.001*"treaty" + 0.001*"km"
# 2024-01-29 10:50:00,289 : INFO : topic diff=8.319936, rho=1.000000
# 2024-01-29 10:50:01,157 : INFO : -16.329 per-word bound, 82323.6 perplexity estimate based on a held-out corpus of 672 documents with 6132 words
# 2024-01-29 10:50:01,734 : INFO : PROGRESS: pass 1, dispatched chunk #0 = documents up to #2000/4672, outstanding queue size 1
# 2024-01-29 10:50:02,506 : INFO : PROGRESS: pass 1, dispatched chunk #1 = documents up to #4000/4672, outstanding queue size 2
# 2024-01-29 10:50:02,892 : INFO : PROGRESS: pass 1, dispatched chunk #2 = documents up to #4672/4672, outstanding queue size
dispatched chunk #2 = documents up to #4672/4672, outstanding queue size 2
# 2024-01-29 10:50:48,084 : INFO : topic #3 (0.050): 0.006*"afonso" + 0.003*"cyril" + 0.002*"bernoulli" + 0.001*"bohemian" + 0.001*"ants" + 0.001*"johnston" + 0.001*"lawson" + 0.001*"algeria" + 0.001*"djibouti" + 0.001*"cheshire"
# 2024-01-29 10:50:48,084 : INFO : topic #15 (0.050): 0.003*"airports" + 0.003*"unpaved" + 0.003*"albert" + 0.003*"creed" + 0.002*"runways" + 0.002*"tunnel" + 0.002*"gauge" + 0.002*"highways" + 0.002*"anthem" + 0.002*"samoa"
# 2024-01-29 10:50:48,084 : INFO : topic #1 (0.050): 0.002*"amd" + 0.002*"esther" + 0.001*"asp" + 0.001*"balfour" + 0.001*"vu" + 0.001*"ankara" + 0.001*"chromium" + 0.001*"nintendo" + 0.001*"burrows" + 0.001*"linnaeus"
# 2024-01-29 10:50:48,084 : INFO : topic #14 (0.050): 0.002*"braves" + 0.002*"cambrian" + 0.002*"inning" + 0.002*"pitcher" + 0.002*"barbados" + 0.002*"mlb" + 0.002*"epirus" + 0.002*"az" + 0.002*"aspirated" + 0.002*"elf"
# 2024-01-29 10:50:48,084 : INFO : topic #12 (0.050): 0.018*"singer" + 0.018*"actor" + 0.017*"politician" + 0.014*"actress" + 0.013*"footballer" + 0.012*"songwriter" + 0.009*"producer" + 0.007*"screenwriter" + 0.006*"journalist" + 0.006*"guitarist"
# 2024-01-29 10:50:48,088 : INFO : topic diff=0.069631, rho=0.227414
# 2024-01-29 10:50:48,898 : INFO : -13.965 per-word bound, 15988.6 perplexity estimate based on a held-out corpus of 672 documents with 6132 words
# 2024-01-29 10:50:49,454 : INFO : PROGRESS: pass 17, dispatched chunk #0 = documents up to #2000/4672, outstanding queue size 1
# 2024-01-29 10:50:50,234 : INFO : PROGRESS: pass 17, dispatched chunk #1 = documents up to #4000/4672, outstanding queue size 2
# 2024-01-29 10:50:50,595 : INFO : PROGRESS: pass 17, dispatched chunk #2 = documents up to #4672/4672, outstanding queue size 2
# 2024-01-29 10:50:50,998 : INFO : topic #2 (0.050): 0.003*"aircraft" + 0.002*"km" + 0.002*"parliament" + 0.002*"jpg" + 0.002*"election" + 0.002*"democratic" + 0.002*"lake" + 0.002*"airport" + 0.002*"constitution" + 0.002*"railway"
# 2024-01-29 10:50:50,998 : INFO : topic #12 (0.050): 0.018*"singer" + 0.018*"actor" + 0.017*"politician" + 0.015*"actress" + 0.013*"footballer" + 0.012*"songwriter" + 0.009*"producer" + 0.007*"screenwriter" + 0.006*"journalist" + 0.006*"guitarist"
# 2024-01-29 10:50:50,998 : INFO : topic #19 (0.050): 0.003*"pope" + 0.003*"christ" + 0.002*"apollo" + 0.002*"churches" + 0.002*"jesus" + 0.002*"bishop" + 0.002*"algebra" + 0.002*"px" + 0.002*"constantine" + 0.002*"alexandria"
# 2024-01-29 10:50:51,002 : INFO : topic #15 (0.050): 0.003*"unpaved" + 0.003*"albert" + 0.003*"airports" + 0.003*"creed" + 0.002*"tunnel" + 0.002*"runways" + 0.002*"gauge" + 0.002*"highways" + 0.002*"anthem" + 0.002*"samoa"
# 2024-01-29 10:50:51,002 : INFO : topic #16 (0.050): 0.009*"constellation" + 0.008*"magnitude" + 0.006*"stars" + 0.004*"ngc" + 0.004*"constellations" + 0.003*"galaxy" + 0.003*"cluster" + 0.003*"brightest" + 0.002*"missile" + 0.002*"chromosome"
# 2024-01-29 10:50:51,002 : INFO : topic diff=0.057870, rho=0.221752
# 2024-01-29 10:50:51,789 : INFO : -13.959 per-word bound, 15922.4 perplexity estimate based on a held-out corpus of 672 documents with 6132 words
# 2024-01-29 10:50:52,352 : INFO : PROGRESS: pass 18, dispatched chunk #0 = documents up to #2000/4672, outstanding queue size 1
# 2024-01-29 10:50:53,120 : INFO : PROGRESS: pass 18, dispatched chunk #1 = documents up to #4000/4672, outstanding queue size 2
# 2024-01-29 10:50:53,499 : INFO : PROGRESS: pass 18, dispatched chunk #2 = documents up to #4672/4672, outstanding queue size 2
# 2024-01-29 10:50:53,895 : INFO : topic #18 (0.050): 0.004*"stations" + 0.004*"telephones" + 0.003*"mobile" + 0.003*"cipher" + 0.003*"cellular" + 0.003*"telephone" + 0.002*"encryption" + 0.002*"esperanto" + 0.002*"providers" + 0.002*"computable"
# 2024-01-29 10:50:53,895 : INFO : topic #4 (0.050): 0.002*"dartmouth" + 0.002*"apache" + 0.002*"adobe" + 0.002*"athena" + 0.002*"bandwidth" + 0.001*"amplifier" + 0.001*"amplifiers" + 0.001*"bayesian" + 0.001*"cannibalism" + 0.001*"afrikaans"
# 2024-01-29 10:50:53,899 : INFO : topic #9 (0.050): 0.003*"djibouti" + 0.003*"alaska" + 0.002*"bicarbonate" + 0.002*"broncos" + 0.001*"crowley" + 0.001*"belize" + 0.001*"mclean" + 0.001*"beaver" + 0.001*"hubbard" + 0.001*"garbage"
# 2024-01-29 10:50:53,899 : INFO : topic #11 (0.050): 0.002*"dynamite" + 0.001*"caesium" + 0.001*"beryllium" + 0.001*"adhesive" + 0.001*"badminton" + 0.001*"folio" + 0.001*"thousand" + 0.001*"donaldson" + 0.001*"caltech" + 0.001*"bo"
# 2024-01-29 10:50:53,899 : INFO : topic #5 (0.050): 0.007*"cell" + 0.004*"cells" + 0.004*"proteins" + 0.004*"brunei" + 0.003*"membrane" + 0.003*"protein" + 0.003*"bt" + 0.002*"glucose" + 0.002*"cardinality" + 0.002*"virus"
# 2024-01-29 10:50:53,899 : INFO : topic diff=0.048416, rho=0.216493
# 2024-01-29 10:50:54,687 : INFO : -13.951 per-word bound, 15839.0 perplexity estimate based on a held-out corpus of 672 documents with 6132 words
# 2024-01-29 10:50:55,286 : INFO : PROGRESS: pass 19, dispatched chunk #0 = documents up to #2000/4672, outstanding queue size 1
# 2024-01-29 10:50:56,036 : INFO : PROGRESS: pass 19, dispatched chunk #1 = documents up to #4000/4672, outstanding queue size 2
# 2024-01-29 10:50:56,416 : INFO : PROGRESS: pass 19, dispatched chunk #2 = documents up to #4672/4672, outstanding queue size 2
# 2024-01-29 10:50:56,837 : INFO : topic #11 (0.050): 0.002*"dynamite" + 0.001*"caesium" + 0.001*"beryllium" + 0.001*"adhesive" + 0.001*"badminton" + 0.001*"folio" + 0.001*"thousand" + 0.001*"donaldson" + 0.001*"caltech" + 0.001*"bo"
# 2024-01-29 10:50:56,841 : INFO : topic #15 (0.050): 0.003*"unpaved" + 0.003*"albert" + 0.003*"creed" + 0.002*"airports" + 0.002*"tunnel" + 0.002*"gauge" + 0.002*"runways" + 0.002*"highways" + 0.002*"anthem" + 0.002*"samoa"
# 2024-01-29 10:50:56,841 : INFO : topic #3 (0.050): 0.006*"afonso" + 0.003*"cyril" + 0.002*"bernoulli" + 0.001*"bohemian" + 0.001*"ants" + 0.001*"johnston" + 0.001*"algeria" + 0.001*"lawson" + 0.001*"cheshire" + 0.001*"cyrus"
# 2024-01-29 10:50:56,841 : INFO : topic #7 (0.050): 0.002*"album" + 0.001*"disambiguation" + 0.001*"dna" + 0.001*"players" + 0.001*"jpg" + 0.001*"universe" + 0.001*"mathematics" + 0.001*"songs" + 0.001*"engine" + 0.001*"scotland"
# 2024-01-29 10:50:56,841 : INFO : topic #6 (0.050): 0.005*"disease" + 0.003*"brain" + 0.003*"bacteria" + 0.003*"est" + 0.003*"patients" + 0.003*"statistics" + 0.003*"symptoms" + 0.003*"diseases" + 0.002*"organisms" + 0.002*"tfr"
# 2024-01-29 10:50:56,845 : INFO : topic diff=0.040788, rho=0.211591
# 2024-01-29 10:50:57,657 : INFO : -13.946 per-word bound, 15781.9 perplexity estimate based on a held-out corpus of 672 documents with 6132 words
# 2024-01-29 10:50:57,684 : INFO : LdaMulticore lifecycle event {'msg': 'trained LdaMulticore<num_terms=19960, num_topics=20, decay=0.5, chunksize=2000> in 63.05s', 'datetime': '2024-01-29T10:50:57.684173', 'gensim': '4.3.2', 'python': '3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'created'}
# 2024-01-29 10:50:57,684 : INFO : topic #0 (0.050): 0.004*"israel" + 0.004*"rica" + 0.004*"judah" + 0.003*"beer" + 0.003*"yahweh" + 0.003*"bible" + 0.003*"prophet" + 0.003*"hebrew" + 0.003*"israelites" + 0.003*"aramaic"
# 2024-01-29 10:50:57,684 : INFO : topic #1 (0.050): 0.002*"amd" + 0.002*"esther" + 0.001*"asp" + 0.001*"nintendo" + 0.001*"balfour" + 0.001*"vu" + 0.001*"chromium" + 0.001*"ankara" + 0.001*"burrows" + 0.001*"linnaeus"
# 2024-01-29 10:50:57,684 : INFO : topic #2 (0.050): 0.003*"aircraft" + 0.002*"km" + 0.002*"parliament" + 0.002*"jpg" + 0.002*"election" + 0.002*"democratic" + 0.002*"lake" + 0.002*"airport" + 0.002*"constitution" + 0.001*"railway"
# 2024-01-29 10:50:57,684 : INFO : topic #3 (0.050): 0.006*"afonso" + 0.003*"cyril" + 0.002*"bernoulli" + 0.001*"bohemian" + 0.001*"ants" + 0.001*"johnston" + 0.001*"algeria" + 0.001*"lawson" + 0.001*"cheshire" + 0.001*"cyrus"
# 2024-01-29 10:50:57,688 : INFO : topic #4 (0.050): 0.002*"dartmouth" + 0.002*"apache" + 0.002*"adobe" + 0.002*"athena" + 0.002*"bandwidth" + 0.001*"amplifier" + 0.001*"amplifiers" + 0.001*"bayesian" + 0.001*"cannibalism" + 0.001*"afrikaans"
# 2024-01-29 10:50:57,688 : INFO : topic #5 (0.050): 0.007*"cell" + 0.004*"cells" + 0.004*"proteins" + 0.004*"brunei" + 0.003*"membrane" + 0.003*"protein" + 0.003*"bt" + 0.002*"glucose" + 0.002*"cardinality" + 0.002*"atp"
# 2024-01-29 10:50:57,688 : INFO : topic #6 (0.050): 0.005*"disease" + 0.003*"brain" + 0.003*"bacteria" + 0.003*"est" + 0.003*"patients" + 0.003*"statistics" + 0.003*"symptoms" + 0.003*"diseases" + 0.002*"organisms" + 0.002*"tfr"
# 2024-01-29 10:50:57,688 : INFO : topic #7 (0.050): 0.002*"album" + 0.001*"disambiguation" + 0.001*"dna" + 0.001*"players" + 0.001*"jpg" + 0.001*"universe" + 0.001*"mathematics" + 0.001*"songs" + 0.001*"engine" + 0.001*"scotland"
# 2024-01-29 10:50:57,688 : INFO : topic #8 (0.050): 0.003*"cornish" + 0.002*"corona" + 0.002*"entropy" + 0.001*"sonata" + 0.001*"boomerang" + 0.001*"bricks" + 0.001*"conditioning" + 0.001*"amateur" + 0.001*"benchmark" + 0.001*"expansive"
# 2024-01-29 10:50:57,688 : INFO : topic #9 (0.050): 0.003*"djibouti" + 0.003*"alaska" + 0.002*"bicarbonate" + 0.002*"broncos" + 0.001*"crowley" + 0.001*"belize" + 0.001*"mclean" + 0.001*"beaver" + 0.001*
# [(0,
#   '0.004*"israel" + 0.004*"rica" + 0.004*"judah" + 0.003*"beer" + 0.003*"yahweh" + 0.003*"bible" + 0.003*"prophet" + 0.003*"hebrew" + 0.003*"israelites" + 0.003*"aramaic"'),
#  (1,
#   '0.002*"amd" + 0.002*"esther" + 0.001*"asp" + 0.001*"nintendo" + 0.001*"balfour" + 0.001*"vu" + 0.001*"chromium" + 0.001*"ankara" + 0.001*"burrows" + 0.001*"linnaeus"'),
#  (2,
#   '0.003*"aircraft" + 0.002*"km" + 0.002*"parliament" + 0.002*"jpg" + 0.002*"election" + 0.002*"democratic" + 0.002*"lake" + 0.002*"airport" + 0.002*"constitution" + 0.001*"railway"'),
#  (3,
#   '0.006*"afonso" + 0.003*"cyril" + 0.002*"bernoulli" + 0.001*"bohemian" + 0.001*"ants" + 0.001*"johnston" + 0.001*"algeria" + 0.001*"lawson" + 0.001*"cheshire" + 0.001*"cyrus"'),
#  (4,
#   '0.002*"dartmouth" + 0.002*"apache" + 0.002*"adobe" + 0.002*"athena" + 0.002*"bandwidth" + 0.001*"amplifier" + 0.001*"amplifiers" + 0.001*"bayesian" + 0.001*"cannibalism" + 0.001*"afrikaans"'),
#  (5,
#   '0.007*"cell" + 0.004*"cells" + 0.004*"proteins" + 0.004*"brunei" + 0.003*"membrane" + 0.003*"protein" + 0.003*"bt" + 0.002*"glucose" + 0.002*"cardinality" + 0.002*"atp"'),
#  (6,
#   '0.005*"disease" + 0.003*"brain" + 0.003*"bacteria" + 0.003*"est" + 0.003*"patients" + 0.003*"statistics" + 0.003*"symptoms" + 0.003*"diseases" + 0.002*"organisms" + 0.002*"tfr"'),
#  (7,
#   '0.002*"album" + 0.001*"disambiguation" + 0.001*"dna" + 0.001*"players" + 0.001*"jpg" + 0.001*"universe" + 0.001*"mathematics" + 0.001*"songs" + 0.001*"engine" + 0.001*"scotland"'),
#  (8,
#   '0.003*"cornish" + 0.002*"corona" + 0.002*"entropy" + 0.001*"sonata" + 0.001*"boomerang" + 0.001*"bricks" + 0.001*"conditioning" + 0.001*"amateur" + 0.001*"benchmark" + 0.001*"expansive"'),
#  (9,
#   '0.003*"djibouti" + 0.003*"alaska" + 0.002*"bicarbonate" + 0.002*"broncos" + 0.001*"crowley" + 0.001*"belize" + 0.001*"mclean" + 0.001*"beaver" + 0.001*"hubbard" + 0.001*"garbage"'),
#  (10,
#   '0.006*"alfonso" + 0.004*"cyprus" + 0.004*"burkina" + 0.004*"faso" + 0.004*"salvador" + 0.004*"byzantine" + 0.004*"athens" + 0.003*"constantinople" + 0.003*"brandenburg" + 0.003*"basque"'),
#  (11,
#   '0.002*"dynamite" + 0.001*"caesium" + 0.001*"beryllium" + 0.001*"adhesive" + 0.001*"badminton" + 0.001*"folio" + 0.001*"thousand" + 0.001*"donaldson" + 0.001*"caltech" + 0.001*"bo"'),
#  (12,
#   '0.018*"singer" + 0.018*"actor" + 0.017*"politician" + 0.015*"actress" + 0.013*"footballer" + 0.013*"songwriter" + 0.009*"producer" + 0.007*"screenwriter" + 0.006*"journalist" + 0.006*"guitarist"'),
#  (13,
#   '0.003*"episode" + 0.002*"comic" + 0.002*"episodes" + 0.002*"movie" + 0.002*"baseball" + 0.002*"darwin" + 0.002*"comics" + 0.002*"batman" + 0.002*"broadway" + 0.002*"doctor"'),
#  (14,
#   '0.002*"braves" + 0.002*"pitcher" + 0.002*"cambrian" + 0.002*"inning" + 0.002*"barbados" + 0.002*"az" + 0.002*"aspirated" + 0.002*"elf" + 0.002*"alexis" + 0.002*"mlb"'),
#  (15,
#   '0.003*"unpaved" + 0.003*"albert" + 0.003*"creed" + 0.002*"airports" + 0.002*"tunnel" + 0.002*"gauge" + 0.002*"runways" + 0.002*"highways" + 0.002*"anthem" + 0.002*"samoa"'),
#  (16,
#   '0.009*"constellation" + 0.008*"magnitude" + 0.006*"stars" + 0.004*"ngc" + 0.004*"constellations" + 0.003*"galaxy" + 0.003*"cluster" + 0.003*"brightest" + 0.002*"missile" + 0.002*"chromosome"'),
#  (17,
#   '0.007*"acid" + 0.004*"compounds" + 0.004*"carbon" + 0.003*"reaction" + 0.003*"ch" + 0.003*"isotopes" + 0.003*"reactions" + 0.002*"oxidation" + 0.002*"db" + 0.002*"acids"'),
#  (18,
#   '0.004*"stations" + 0.004*"telephones" + 0.003*"mobile" + 0.003*"cipher" + 0.003*"cellular" + 0.003*"telephone" + 0.002*"esperanto" + 0.002*"encryption" + 0.002*"providers" + 0.002*"broadband"'),
#  (19,
#   '0.003*"pope" + 0.003*"christ" + 0.002*"apollo" + 0.002*"churches" + 0.002*"jesus" + 0.002*"bishop" + 0.002*"algebra" + 0.002*"px" + 0.002*"constantine" + 0.002*"alexandria"')]

# %% [markdown]
# ## Tweety
#
# W parach stwórzcie model LDA w oparciu o załączone Tweety. W tym celu należy przekonwertować pliki tekstowe na reprezentację wektorową zapisując wcześniej mapowanie id->słowo w postaci słownika. Opis jak stworzyć wymienione struktury danych można znaleźć na stronie: https://radimrehurek.com/gensim/tut1.html.

# %% [markdown]
# **Zad. 1: Wczytaj tweety z pliku tweets.tsv do zmiennej `tweets`.**

# %%
import gensim
import logging
import nltk
import re
import pandas as pd

stopwords = ["a", "about", "after", "all", "am", "an", "and", "any", "are", "as", "at", "be", "because", "been",
            "before", "being", "between", "both", "by", "could", "did", "do", "does", "doing", "during", "each",
            "for", "from", "further", "had", "has", "have", "having", "he", "he'd", "he'll", "he's", "her", "here",
            "here's", "hers", "herself", "him", "himself", "his", "how", "how's", "i", "i'd", "i'll", "i'm", "i've",
            "in", "into", "is", "it", "it's", "its", "itself", "let's", "me", "more", "most", "my", "myself", "of",
            "on", "once", "only", "or", "other", "ought", "our", "ours", "ourselves", "own", "shan't", "she", "she'd",
            "she'll", "she's", "should", "so", "some", "such", "than", "that", "that's", "the", "their", "theirs",
            "them", "themselves", "then", "there", "there's", "these", "they", "they'd", "they'll", "they're",
            "they've", "this", "those", "through", "to", "until", "up", "very", "was", "wasn't", "we", "we'd",
            "we'll", "we're", "we've", "were", "weren't", "what", "what's", "when", "when's", "where", "where's",
            "which", "while", "who", "who's", "whom", "with", "would", "you", "you'd", "you'll", "you're", "you've",
            "your", "yours", "yourself", "yourselves", "above", "again", "against", "aren't", "below", "but", "can't",
            "cannot", "couldn't", "didn't", "doesn't", "don't", "down", "few", "hadn't", "hasn't", "haven't", "if",
            "isn't", "mustn't", "no", "nor", "not", "off", "out", "over", "shouldn't", "same", "too", "under", "why",
            "why's", "won't", "wouldn't"]

column_names = ["id", "idk", "text"]
tweets = pd.read_csv('tweets.tsv', sep='\t', header=None, names=column_names)
tweets.head()
# Out:
#                    id idk                                               text
# 0  628949369883000832   ?  dear @Microsoft the newOoffice for Mac is grea...
# 1  628976607420645377   ?  @Microsoft how about you make a system that do...
# 2  629023169169518592   ?                                      Not Available
# 3  629179223232479232   ?                                      Not Available
# 4  629186282179153920   ?  If I make a game as a #windows10 Universal App...

# %% [markdown]
# **Zad. 2: Dokonaj tokenizacji słów, usuń te z stoplisty (`stopwords`) oraz występujące tylko raz. Wynik przypisz do zmiennej `texts`.**

# %%
texts = tweets['text'].to_string(index=False)
# tweets.apply(lambda row: nltk.word_tokenize(row['text']), axis=1)
texts = [nltk for text in texts]

# %%
texts
# Out:
# 'dear @Microsoft the newOoffice for Mac is great...\n@Microsoft how about you make a system that doe...\n                                     Not Available\n                                     Not Available\nIf I make a game as a #windows10 Universal App....\nMicrosoft, I may not prefer your gaming branch ...\n@MikeWolf1980 @Microsoft I will be downgrading ...\n@Microsoft 2nd computer with same error!!! #Win...\nJust ordered my 1st ever tablet; @Microsoft Sur...\nAfter attempting a reinstall, it still bricks, ...\nSunday morning, quiet day so time to welcome in...\nDid @Microsoft break Windows 10? Was working fi...\n@MSAU @Microsoft spent over 40 mins &amp; gave ...\n@spyderharrison @Microsoft the reason I ask is ...\nInnovation for jobs is just around the corner -...\nOK this is my pure speculation.  @Microsoft own...\nWe are still taking registrations for our Educa...\nFor the 1st time @Skype has a "High Startup imp...\n#teens @BillGates 1st company failed miserably....\n#Vote for @AIESEC to become the 10th Global non...\nTop 5 most searched for Back-to-School topics -...\n@Microsoft support for 365 has been terrible. O...\n@trucker_squigz @Microsoft @MISpeedway @nationw...\n                                     Not Available\n@ScottArbeit @GabeAul @Microsoft isntall the ne...\n@taehongmin1 We have an IOT workshop by @Micros...\n@kenttaylor333 @YourAnonNews @Microsoft the opt...\nHey @Microsoft, I reserved my copy of @Windows ...\n@eyesonfoxorg @Microsoft I\'m still using Vista ...\n@Microsoft Is it normal that it takes hours to ...\n@MisterMetokur @Microsoft @ATT @NSAGov That\'s c...\n@ForbesRussia #MBA #casestudy Namaste 2 #google...\n@Microsoft you may want to fix this... http://t...\nAfter 75 minutes of being on hold with @Microso...\n@Microsoft On hold with support for 52 minutes ...\nBeyond frustrated with my #Xbox360 right now, a...\n@Microsoft Heard you are a software company. Wh...\n                                     Not Available\nPAX Prime Thursday is overloaded for me with @M...\nI traveled to Redmond today. I\'m visiting with ...\nHave you heard the news? Our next meetup is on ...\n@Microsoft @Windows Daily windows updates suck!...\nCall from "John" @Microsoft "hello, i\'d like to...\nWe\'re excited to learn about #cloud #analytics ...\nPet adoptions are $10 this Friday @BFAS_LA than...\n@TechCrunch the phone will be too tall and bulk...\nI thought @Microsoft was retiring the Lumia lin...\n@microsoft using Office 2013\'s Bing dictionary....\nHERE today, gone tomorrow- but still here! A sh...\n@Microsoft "For a limited time"   What about an...\nGood Friday morning. This city is changing. Are...\nhttp://t.co/luX5VvBrmJ   Register 4 the NACR Sk...\nDid you know our Lunch&amp;Learns are now open ...\nI\'ve just been told for the 5th time that my ca...\nNow I\'m trying to get to @MicrosoftHelps @Micro...\nSpending the day on the phone with @Microsoft. ...\n@Microsoft may just reinvent personal computing...\n@Microsoft - congratulations on the 20th Birth ...\nLooks like @Microsoft may still be in the hands...\n@SuzanneMalveaux @hollyrpeete @Microsoft @sfuji...\nEnjoying feasibility workshop replacing #Cognos...\n@Microsoft @MicrosoftHelps For the 2nd time I h...\nI hate you @Adobe, u crash more then any other ...\n                                     Not Available\n@tomwarren @microsoft the lumia cityman looks t...\n@joebelfiore @GabeAul @Microsoft @Lumia @satyan...\n@business @google @Microsoft - nothing new unde...\nhave u suggested to @microsoft that going shopp...\n3rd rep just hung up on me. Absolutely devastat...\n@Microsoft may you PLEASE release versions of W...\nStartup your Monday in the right way. Apply 2 o...\nPredictive Analytics with @Microsoft #Azure #Ma...\n@Microsoft you guys may piss me off with the Xb...\nI can\'t wait to speak at @Microsoft\'s #MSAPC201...\nHappy hour at @Microsoft #msapc2015 with @sarah...\n#llvm 3.7 is the 2nd release to incorporate con...\n@BundyB @Microsoft I may have missed  ...

# %% [markdown]
# **Zad. 3: Stwórz słownik id->słowo i przypisz do zmiennej `id2word`.**

# %%
id2word = None

# %% [markdown]
# **Zad. 4: Stwórz reprezentację wektorową korpusu (macierz wektorów TF-IDF), wynik przypisz do zmiennej `mm`.**

# %%
mm=None

# %% [markdown]
# **Zad. 5: Odpal poniższy kod i odkryj 10 tematów za pomocą algorytmu LDA. Jeśli masz czas, zwiększ wartości parametrów num_topics i passes przy tworzeniu modelu LDA, i sprawdź jak to wpłynie na rezultat.**

# %%
# # Włączamy logowanie, żeby śledzić postępy algorytmu (to akurat nie będzie działać w Jupyter Notebooku,
# # ale warto o tym wspomnieć)
# logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
#
# lda = gensim.models.ldamodel.LdaModel(corpus=mm, id2word=id2word, num_topics=10, update_every=0, passes=20)
# # alternatywnie lda = gensim.models.LdaMulticore(corpus=mm, id2word=id2word, num_topics=10, passes=20)
# lda.print_topics(10)

# %% [markdown]
# **Zad. 6*: Na podstawie zbudowanego modelu określ proporcje tematów w następującym tweecie:
# `Zlatan is looking mighty attractive at the moment,if LVG doesn't get a striker by Tuesday, I really don't fancy us scoring goals this season`. Jeśli zostało niewiele czasu, przejdź od razu do wizualizacji.**

# %%
# new_tweet = "Zlatan is looking mighty attractive at the moment,if LVG doesn't get a striker by Tuesday, I really don't fancy us scoring goals this season"
# new_tweet_text = ???
# new_tweet_mm = id2word.doc2bow(new_tweet_text)
# new_tweet_lda = ???
# print(new_tweet_lda)

# %% [markdown]
# ## Wizualizacja
#
# Spróbujemy teraz zwizualizować uzyskane tematy. Podążaj za komentarzami a powinno się udać.
#
# P.S. Możesz uruchomić tę wizualizację również dla tematów odkrytych z Wikipedii...
#
# **Zad. 7: Zwizualizuj uzyskane tematy.**

# %%
# # Poniższy kod korzysta modułu pyLDAvis z githuba:
# # https://github.com/bmabey/pyLDAvis

# import pyLDAvis
# import pyLDAvis.gensim
# pyLDAvis.enable_notebook()

# pyLDAvis.gensim.prepare(lda, mm, id2word)
